# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

from src.data_utils import download_prices, save_log_returns

# %%
tickers = ["AAPL", "NVDA", "VOO", "JPM", "GLD", "BTC-USD", "PFE"]
start_date = "2018-01-01"
end_date = "2023-12-31"

download_prices(tickers, start_date, end_date)

save_log_returns(tickers)

# %%
df = pd.read_csv("data/processed/AAPL_log_returns.csv", index_col="Date", parse_dates=True)
df.cumsum().plot(title="AAPL Cumulative Log Returns", figsize=(10, 5))
plt.grid()
plt.show()
